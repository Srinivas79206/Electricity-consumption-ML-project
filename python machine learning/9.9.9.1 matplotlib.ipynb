# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
x=np.linspace(0,50,11)

# %%
x
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])

# %%
y=x**2

# %%
y
# Out:
# array([   0.,   25.,  100.,  225.,  400.,  625.,  900., 1225., 1600.,
#        2025., 2500.])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title('demograph')
# Out:
# Text(0.5, 1.0, 'demograph')

# %%
plt.plot(x,y)
plt.title('demograph')
plt.xlabel('value of x')
plt.ylabel('value of y')
# Out:
# Text(0, 0.5, 'value of y')

# %%
plt.plot(x,y)
plt.title('demograph')
plt.xlabel('value of x')
plt.ylabel('value of y')
plt.show()# this is in case of python

# %%
plt.plot(x,y,'r')
plt.title('demograph')
plt.xlabel('value of x')
plt.ylabel('value of y')
plt.show()

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'r*')
plt.subplot(1,3,2)
plt.plot(y,x,'b')
plt.subplot(1,3,3)
plt.plot(x,y,'g--*')
plt.title('demo graph')
plt.xlabel('value of x')
plt.ylabel('value of y')
plt.show()

# %%
x
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])

# %%
y
# Out:
# array([   0.,   25.,  100.,  225.,  400.,  625.,  900., 1225., 1600.,
#        2025., 2500.])

# %%
plt.bar([1,5,6,7],[9,11,23,17])
plt.show()

# %%
plt.pie(x,labels=['a','b','c','d','e','f','g','h','i','j','k'])
# Out:
# ([<matplotlib.patches.Wedge at 0x177a1e84460>,
#   <matplotlib.patches.Wedge at 0x177a1e84970>,
#   <matplotlib.patches.Wedge at 0x177a1e84e50>,
#   <matplotlib.patches.Wedge at 0x177a1e8e370>,
#   <matplotlib.patches.Wedge at 0x177a1e8e850>,
#   <matplotlib.patches.Wedge at 0x177a1e8ed30>,
#   <matplotlib.patches.Wedge at 0x177a1eb9250>,
#   <matplotlib.patches.Wedge at 0x177a1eb9730>,
#   <matplotlib.patches.Wedge at 0x177a1eb9c10>,
#   <matplotlib.patches.Wedge at 0x177a300f130>,
#   <matplotlib.patches.Wedge at 0x177a1e84430>],
#  [Text(1.1, 0.0, 'a'),
#   Text(1.0982060144323316, 0.06279768996272098, 'b'),
#   Text(1.0714131104390903, 0.24914643641688675, 'c'),
#   Text(0.9578206904715764, 0.5409062071233356, 'd'),
#   Text(0.6717126826129879, 0.871092458936974, 'e'),
#   Text(0.156546339476946, 1.0888035835706864, 'f'),
#   Text(-0.5133340491307307, 0.9728762274837682, 'g'),
#   Text(-1.0360287953626528, 0.36965434554379384, 'h'),
#   Text(-0.9578207031323998, -0.5409061847039242, 'i'),
#   Text(-0.09413258651866149, -1.0959648973189364, 'j'),
#   Text(0.9253788411904255, -0.5947049691040638, 'k')])
